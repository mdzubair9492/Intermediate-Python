# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Introducing new data**

# %%
##### DATA ####
# 5+ years of stock prices : Apple, Facebook , Microsoft , Google and Amazon

# %%
tech_url='https://andybek.com/pandas-tech'

# %%
tech=pd.read_csv(tech_url)

# %%
tech.head(10)
# Out:
#          date  month  year  day   name    open   close    high     low  \
# 0  2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19
# 1  2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86
# 2  2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13
# 3  2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10
# 4  2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02
# 5  2014-01-03      1  2014    3     FB   55.00   54.56   55.65   54.53
# 6  2014-01-03      1  2014    3  GOOGL  557.50  552.50  558.47  552.47
# 7  2014-01-03      1  2014    3   MSFT   37.20   36.91   37.22   36.60
# 8  2014-01-03      1  2014    3   AAPL   79.00   77.28   79.10   77.20
# 9  2014-01-03      1  2014    3   AMZN  398.29  396.44  402.71  396.22
#
#      volume volume_type
# 0  43257622      medium
# 1   8398851         low
# 2   1822719      medium
# 3  30643745      medium
# 4   2140246      medium
# 5  38287706      medium
# ...

# %%
tech.shape
# Out:
# (7105, 11)

# %%
tech.year.value_counts()/5
# Out:
# 2014    252.0
# 2015    252.0
# 2016    252.0
# 2017    251.0
# 2018    251.0
# 2019    163.0
# Name: year, dtype: float64

# %%
tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7105 entries, 0 to 7104
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         7105 non-null   object
#  1   month        7105 non-null   int64
#  2   year         7105 non-null   int64
#  3   day          7105 non-null   int64
#  4   name         7105 non-null   object
#  5   open         7105 non-null   float64
#  6   close        7105 non-null   float64
#  7   high         7105 non-null   float64
#  8   low          7105 non-null   float64
#  9   volume       7105 non-null   int64
#  10  volume_type  7105 non-null   object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 610.7+ KB

# %% [markdown]
# **Index and RangeIndex**

# %%
tech.volume.head()
# Out:
# 0    43257622
# 1     8398851
# 2     1822719
# 3    30643745
# 4     2140246
# Name: volume, dtype: int64

# %%
tech.head(10)
# Out:
#          date  month  year  day   name    open   close    high     low  \
# 0  2014-01-02      1  2014    2     FB   54.86   54.71   55.22   54.19
# 1  2014-01-02      1  2014    2   AAPL   79.38   79.02   79.58   78.86
# 2  2014-01-02      1  2014    2  GOOGL  557.73  556.56  558.88  554.13
# 3  2014-01-02      1  2014    2   MSFT   37.35   37.16   37.40   37.10
# 4  2014-01-02      1  2014    2   AMZN  398.80  397.97  399.36  394.02
# 5  2014-01-03      1  2014    3     FB   55.00   54.56   55.65   54.53
# 6  2014-01-03      1  2014    3  GOOGL  557.50  552.50  558.47  552.47
# 7  2014-01-03      1  2014    3   MSFT   37.20   36.91   37.22   36.60
# 8  2014-01-03      1  2014    3   AAPL   79.00   77.28   79.10   77.20
# 9  2014-01-03      1  2014    3   AMZN  398.29  396.44  402.71  396.22
#
#      volume volume_type
# 0  43257622      medium
# 1   8398851         low
# 2   1822719      medium
# 3  30643745      medium
# 4   2140246      medium
# 5  38287706      medium
# ...

# %%
type(tech.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
# RangeIndex is immutable

# %%
type(tech.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# bothe inherit from indexes

# %%
tech.set_index('date').loc['2019-08-01']
# Out:
#             month  year  day   name     open    close     high      low  \
# date
# 2019-08-01      8  2019    1  GOOGL  1217.63  1211.78  1236.30  1207.00
# 2019-08-01      8  2019    1     FB   194.17   192.73   198.47   190.88
# 2019-08-01      8  2019    1   MSFT   137.00   138.06   140.94   136.93
# 2019-08-01      8  2019    1   AMZN  1871.72  1855.32  1897.92  1844.01
# 2019-08-01      8  2019    1   AAPL   213.90   208.43   218.03   206.74
#
#               volume volume_type
# date
# 2019-08-01   1771271      medium
# 2019-08-01  17777013      medium
# 2019-08-01  40557502      medium
# 2019-08-01   4713311      medium
# 2019-08-01  54017922      medium

# %% [markdown]
# **Creating a multiindex**

# %%
tech.set_index(['date','name'],inplace=True) # creating multiindex or hierarchical index

# %%
tech.head(10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
# 2014-01-03 FB         1  2014    3   55.00   54.56   55.65   54.53  38287706
#            GOOGL      1  2014    3  557.50  552.50  558.47  552.47   1669229
#            MSFT       1  2014    3   37.20   36.91   37.22   36.60  31134795
#            AAPL       1  2014    3   79.00   77.28   79.10   77.20  14043410
#            AMZN       1  2014    3  398.29  396.44  402.71  396.22   2213512
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
# ...

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# **Multiindex from read_csv()**

# %%
pd.read_csv(tech_url,index_col=['date','name'])
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %% [markdown]
# **Indexing hierarchical dataframes**

# %%
tech.head(10)
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB         1  2014    2   54.86   54.71   55.22   54.19  43257622
#            AAPL       1  2014    2   79.38   79.02   79.58   78.86   8398851
#            GOOGL      1  2014    2  557.73  556.56  558.88  554.13   1822719
#            MSFT       1  2014    2   37.35   37.16   37.40   37.10  30643745
#            AMZN       1  2014    2  398.80  397.97  399.36  394.02   2140246
# 2014-01-03 FB         1  2014    3   55.00   54.56   55.65   54.53  38287706
#            GOOGL      1  2014    3  557.50  552.50  558.47  552.47   1669229
#            MSFT       1  2014    3   37.20   36.91   37.22   36.60  31134795
#            AAPL       1  2014    3   79.00   77.28   79.10   77.20  14043410
#            AMZN       1  2014    3  398.29  396.44  402.71  396.22   2213512
#
#                  volume_type
# date       name
# 2014-01-02 FB         medium
# ...

# %%
tech.loc['2014-01-02','GOOGL']
# Out:
# month                1
# year              2014
# day                  2
# open            557.73
# close           556.56
# high            558.88
# low             554.13
# volume         1822719
# volume_type     medium
# Name: (2014-01-02, GOOGL), dtype: object

# %%
tech.loc['2014-01-02','GOOGL'].close
# Out:
# 556.56

# %%
tech.iloc[2,4]
# Out:
# 556.56

# %%
tech.loc[('2014-01-02','GOOGL'),'close']
# Out:
# 556.56

# %%
tech.loc[('2014-01-02','AAPL'),'open':'close']
# Out:
# open     79.38
# close    79.02
# Name: (2014-01-02, AAPL), dtype: float64

# %% [markdown]
# **Indexing ranges and slices**

# %%
# select multiple days

# %%
tech.loc[(['2015-01-06','2015-01-07'],['FB','AMZN']),:]
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2015-01-06 FB        1  2015    6   77.23   76.15   77.59   75.36  27399288
#            AMZN      1  2015    6  302.20  295.29  303.00  292.38   3519034
# 2015-01-07 FB        1  2015    7   76.76   76.15   77.36   75.82  22045333
#            AMZN      1  2015    7  297.54  298.42  301.28  295.33   2640349
#
#                 volume_type
# date       name
# 2015-01-06 FB        medium
#            AMZN      medium
# 2015-01-07 FB        medium
#            AMZN      medium

# %%
tech.loc[(['2015-01-06','2015-01-07'],['FB','AMZN']),['close','volume']]
# Out:
#                   close    volume
# date       name
# 2015-01-06 FB     76.15  27399288
#            AMZN  295.29   3519034
# 2015-01-07 FB     76.15  22045333
#            AMZN  298.42   2640349

# %%
# what about slices

# %%
tech.loc['2017-01-03':'2017-01-31','open':'low']
# Out:
#                     open   close    high     low
# date       name
# 2017-01-03 AMZN   757.92  753.67  758.76  747.70
#            FB     116.03  116.86  117.84  115.51
#            MSFT    62.79   62.58   62.84   62.13
#            AAPL   115.80  116.15  116.33  114.76
#            GOOGL  800.62  808.01  811.44  796.89
# ...                  ...     ...     ...     ...
# 2017-01-31 MSFT    64.86   64.65   65.15   64.26
#            AAPL   121.15  121.35  121.39  120.62
#            FB     130.17  130.32  130.66  129.52
#            GOOGL  819.50  820.19  823.07  813.40
#            AMZN   823.75  823.48  826.99  819.56
#
# [100 rows x 4 columns]

# %%
# how to isolate google

# %%
tech.loc[('2017-01-03':'2017-01-31','GOOGL'),'open':'volume']
# Out:
#   File "<ipython-input-45-c1a5e4d780ad>", line 1
#     tech.loc[('2017-01-03':'2017-01-31','GOOGL'),'open':'volume']
#                           ^
# SyntaxError: invalid syntax

# %%
tech.loc[(slice('2017-01-03','2017-01-31'),'GOOGL'),'open':'volume']
# Out:
#                     open   close    high     low   volume
# date       name
# 2017-01-03 GOOGL  800.62  808.01  811.44  796.89  1959033
# 2017-01-04 GOOGL  809.89  807.77  813.43  804.11  1515339
# 2017-01-05 GOOGL  807.50  813.02  813.74  805.92  1340535
# 2017-01-06 GOOGL  814.99  825.21  828.96  811.50  2017097
# 2017-01-09 GOOGL  826.37  827.18  830.43  821.62  1408924
# 2017-01-10 GOOGL  827.07  826.01  829.41  823.14  1197442
# 2017-01-11 GOOGL  826.62  829.86  829.90  821.47  1325394
# 2017-01-12 GOOGL  828.38  829.53  830.38  821.01  1350308
# 2017-01-13 GOOGL  831.00  830.94  834.65  829.52  1290182
# 2017-01-17 GOOGL  830.00  827.46  830.18  823.20  1440905
# 2017-01-18 GOOGL  829.80  829.02  829.81  824.08  1027698
# 2017-01-19 GOOGL  829.00  824.37  833.00  823.96  1070454
# 2017-01-20 GOOGL  829.09  828.17  829.24  824.60  1306183
# 2017-01-23 GOOGL  831.61  844.43  845.54  828.70  2457377
# 2017-01-24 GOOGL  846.98  849.53  851.52  842.28  1688375
# ...

# %%
# open prices for FB and AMZN for all the dates in our dfs

# %%
tech.loc[(:,['FB','AMZN']),'open']
# Out:
#   File "<ipython-input-49-91591b563019>", line 1
#     tech.loc[(:,['FB','AMZN']),'open']
#               ^
# SyntaxError: invalid syntax

# %%
tech.loc[(slice(None),['FB','AMZN']),'open']
# Out:
# date        name
# 2014-01-02  FB        54.86
# 2014-01-03  FB        55.00
# 2014-01-06  FB        54.39
# 2014-01-07  FB        57.67
# 2014-01-08  FB        57.59
#                      ...
# 2019-08-19  AMZN    1818.08
# 2019-08-20  AMZN    1814.50
# 2019-08-21  AMZN    1819.39
# 2019-08-22  AMZN    1828.00
# 2019-08-23  AMZN    1793.03
# Name: open, Length: 2842, dtype: float64

# %% [markdown]
# **Use: With pd.IndexSlice()**

# %%
# high and low prices for all days for amzn and fb

# %%
tech.loc[pd.IndexSlice[:,['FB','AMZN']],'high':'low']
# Out:
#                     high      low
# date       name
# 2014-01-02 FB      55.22    54.19
# 2014-01-03 FB      55.65    54.53
# 2014-01-06 FB      57.26    54.05
# 2014-01-07 FB      58.55    57.22
# 2014-01-08 FB      58.41    57.23
# ...                  ...      ...
# 2019-08-19 AMZN  1826.00  1812.61
# 2019-08-20 AMZN  1816.82  1799.88
# 2019-08-21 AMZN  1829.58  1815.00
# 2019-08-22 AMZN  1829.41  1800.10
# 2019-08-23 AMZN  1804.90  1745.23
#
# [2842 rows x 2 columns]

# %%
i=pd.IndexSlice

# %%
tech.loc[i[:,'FB'],'high':'low']
# Out:
#                    high     low
# date       name
# 2014-01-02 FB     55.22   54.19
# 2014-01-03 FB     55.65   54.53
# 2014-01-06 FB     57.26   54.05
# 2014-01-07 FB     58.55   57.22
# 2014-01-08 FB     58.41   57.23
# ...                 ...     ...
# 2019-08-19 FB    187.50  184.85
# 2019-08-20 FB    186.00  182.39
# 2019-08-21 FB    185.90  183.14
# 2019-08-22 FB    184.11  179.91
# 2019-08-23 FB    183.13  176.66
#
# [1421 rows x 2 columns]

# %%
# jan 6 - jan 10

# %%
tech.loc[i['2014-01-06':'2014-01-10',['FB','AMZN']],'high':'low']
# Out:
#                    high     low
# date       name
# 2014-01-06 AMZN  397.00  388.42
#            FB     57.26   54.05
# 2014-01-07 FB     58.55   57.22
#            AMZN  398.47  394.29
# 2014-01-08 AMZN  403.00  396.04
#            FB     58.41   57.23
# 2014-01-09 AMZN  406.89  398.44
#            FB     58.96   56.65
# 2014-01-10 FB     58.30   57.06
#            AMZN  403.76  393.80

# %% [markdown]
# **Cross sections with xs()**

# %%
# xs() is a type of label base indexing

# %%
tech.xs('2019-01-02')
# Out:
#        month  year  day     open    close     high      low    volume  \
# name
# MSFT       1  2019    2    99.55   101.12   101.75    98.94  35329345
# FB         1  2019    2   128.99   135.68   137.51   128.56  28146193
# GOOGL      1  2019    2  1027.20  1054.68  1060.79  1025.28   1593395
# AMZN       1  2019    2  1465.20  1539.13  1553.36  1460.93   7983103
# AAPL       1  2019    2   154.89   157.92   158.85   154.23  37039737
#
#       volume_type
# name
# MSFT       medium
# FB         medium
# GOOGL      medium
# AMZN       medium
# AAPL       medium

# %%
tech.loc[(slice(None),'FB'),:]
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2   54.86   54.71   55.22   54.19  43257622
# 2014-01-03 FB        1  2014    3   55.00   54.56   55.65   54.53  38287706
# 2014-01-06 FB        1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07 FB        1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08 FB        1  2014    8   57.59   58.23   58.41   57.23  56800776
# ...                ...   ...  ...     ...     ...     ...     ...       ...
# 2019-08-19 FB        8  2019   19  186.01  186.17  187.50  184.85   9699661
# 2019-08-20 FB        8  2019   20  185.45  183.81  186.00  182.39  10087592
# 2019-08-21 FB        8  2019   21  185.00  183.55  185.90  183.14   8409548
# 2019-08-22 FB        8  2019   22  183.43  182.04  184.11  179.91  10829509
# 2019-08-23 FB        8  2019   23  180.84  177.75  183.13  176.66  17331221
#
#                 volume_type
# ...

# %%
tech.xs('FB',level=1,drop_level=False)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2014-01-02 FB        1  2014    2   54.86   54.71   55.22   54.19  43257622
# 2014-01-03 FB        1  2014    3   55.00   54.56   55.65   54.53  38287706
# 2014-01-06 FB        1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07 FB        1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08 FB        1  2014    8   57.59   58.23   58.41   57.23  56800776
# ...                ...   ...  ...     ...     ...     ...     ...       ...
# 2019-08-19 FB        8  2019   19  186.01  186.17  187.50  184.85   9699661
# 2019-08-20 FB        8  2019   20  185.45  183.81  186.00  182.39  10087592
# 2019-08-21 FB        8  2019   21  185.00  183.55  185.90  183.14   8409548
# 2019-08-22 FB        8  2019   22  183.43  182.04  184.11  179.91  10829509
# 2019-08-23 FB        8  2019   23  180.84  177.75  183.13  176.66  17331221
#
#                 volume_type
# ...

# %%
tech.xs(('2019-01-02','FB'),level=(0,1))
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2019-01-02 FB        1  2019    2  128.99  135.68  137.51  128.56  28146193
#
#                 volume_type
# date       name
# 2019-01-02 FB        medium

# %% [markdown]
# **Skill challenge**

# %% [markdown]
# *1. From the tech dataframe , select all the stock prices between july 23,2015 and August 17,2016.Assign the dataframe into tech_df2*

# %%
#1st way

# %%
tech.loc['2015-07-23':'2016-08-17']
# Out:
#                   month  year  day    open   close    high     low    volume  \
# date       name
# 2015-07-23 MSFT       7  2015   23   45.27   46.11   46.23   45.10  33934010
#            FB         7  2015   23   96.96   95.44   97.45   94.81  29418833
#            AMZN       7  2015   23  491.66  482.18  491.66  475.70   9374431
#            GOOGL      7  2015   23  691.85  674.73  696.07  671.59   3811598
#            AAPL       7  2015   23  126.20  125.16  127.09  125.06  50999452
# ...                 ...   ...  ...     ...     ...     ...     ...       ...
# 2016-08-17 GOOGL      8  2016   17  800.00  805.42  805.63  796.30   1066070
#            AMZN       8  2016   17  764.41  764.63  765.22  759.20   1891116
#            MSFT       8  2016   17   57.54   57.56   57.68   57.23  18856423
#            FB         8  2016   17  123.66  124.37  124.38  122.85  13794179
#            AAPL       8  2016   17  109.10  109.22  109.37  108.34  25355976
#
# ...

# %%
# xs alternative

# %%
tech_df2=tech.xs(slice('2015-07-23','2016-08-17'),level=0,drop_level=False)

# %% [markdown]
# *2. Select 10 days at random from tech_df2 , containing only AAPL price data*

# %%
tech_df2.xs(level=1,key='AAPL').sample(10)
# Out:
#             month  year  day    open   close    high     low    volume  \
# date
# 2016-06-29      6  2016   29   93.97   94.40   94.55   93.63  36531006
# 2015-08-19      8  2015   19  116.10  115.01  116.52  114.68  48286510
# 2016-03-15      3  2016   15  103.96  104.58  105.18  103.85  40067734
# 2016-04-12      4  2016   12  109.34  110.44  110.50  108.66  27232325
# 2016-06-23      6  2016   23   95.94   96.10   96.29   95.25  32240187
# 2016-03-08      3  2016    8  100.78  101.03  101.76  100.40  31561889
# 2015-08-11      8  2015   11  117.81  113.49  118.18  113.33  97082814
# 2015-09-25      9  2015   25  116.44  114.71  116.69  114.02  56151926
# 2015-12-22     12  2015   22  107.40  107.23  107.72  106.45  32789367
# 2016-02-02      2  2016    2   95.42   94.48   96.04   94.28  37357215
#
#            volume_type
# date
# 2016-06-29      medium
# 2015-08-19      medium
# 2016-03-15      medium
# 2016-04-12      medium
# 2016-06-23      medium
# 2016-03-08      medium
# ...

# %%
# another way

# %%
tech.loc[(slice(None),'AAPL'),:].sample(10)
# Out:
#                  month  year  day    open   close    high     low    volume  \
# date       name
# 2017-10-16 AAPL     10  2017   16  157.90  159.88  160.00  157.65  24121452
# 2017-04-10 AAPL      4  2017   10  143.60  143.17  143.88  142.90  18933397
# 2019-07-31 AAPL      7  2019   31  216.42  213.04  221.37  211.30  69281361
# 2017-02-08 AAPL      2  2017    8  131.35  132.04  132.22  131.22  23004072
# 2019-04-04 AAPL      4  2019    4  194.79  195.69  196.37  193.14  19114275
# 2019-03-06 AAPL      3  2019    6  174.67  174.52  175.49  173.94  20810384
# 2016-05-20 AAPL      5  2016   20   94.64   95.22   95.43   94.52  32025968
# 2017-03-01 AAPL      3  2017    1  137.89  139.79  140.15  137.60  36414585
# 2014-10-13 AAPL     10  2014   13  101.33   99.81  101.78   99.81  53583368
# 2017-09-19 AAPL      9  2017   19  159.51  158.73  159.77  158.44  20810632
#
#                 volume_type
# date       name
# 2017-10-16 AAPL      medium
# 2017-04-10 AAPL      medium
# ...

# %% [markdown]
# *3. Select all the intraday high and low prices for AAPL and GOOGL for all the dates in tech_df2*

# %%
tech_df2.loc[(slice(None),['AAPL','GOOGL']),['high','low']]
# Out:
#                     high     low
# date       name
# 2015-07-23 AAPL   127.09  125.06
# 2015-07-24 AAPL   125.74  123.90
# 2015-07-27 AAPL   123.61  122.12
# 2015-07-28 AAPL   123.91  122.55
# 2015-07-29 AAPL   123.50  122.27
# ...                  ...     ...
# 2016-08-11 GOOGL  813.88  806.00
# 2016-08-12 GOOGL  807.19  803.64
# 2016-08-15 GOOGL  811.36  804.03
# 2016-08-16 GOOGL  804.26  797.00
# 2016-08-17 GOOGL  805.63  796.30
#
# [542 rows x 2 columns]

# %% [markdown]
# **The anatomy of a multiindex object**

# %%
type(tech)
# Out:
# pandas.core.frame.DataFrame

# %%
type(tech.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
tech.index
# Out:
# MultiIndex([('2014-01-02',    'FB'),
#             ('2014-01-02',  'AAPL'),
#             ('2014-01-02', 'GOOGL'),
#             ('2014-01-02',  'MSFT'),
#             ('2014-01-02',  'AMZN'),
#             ('2014-01-03',    'FB'),
#             ('2014-01-03', 'GOOGL'),
#             ('2014-01-03',  'MSFT'),
#             ('2014-01-03',  'AAPL'),
#             ('2014-01-03',  'AMZN'),
#             ...
#             ('2019-08-22',  'MSFT'),
#             ('2019-08-22',    'FB'),
#             ('2019-08-22',  'AMZN'),
#             ('2019-08-22',  'AAPL'),
#             ('2019-08-22', 'GOOGL'),
#             ('2019-08-23',  'MSFT'),
#             ('2019-08-23',  'AAPL'),
#             ('2019-08-23', 'GOOGL'),
#             ('2019-08-23',  'AMZN'),
#             ('2019-08-23',    'FB')],
#            names=['date', 'name'], length=7105)

# %%
tech.index.names # names
# Out:
# FrozenList(['date', 'name'])

# %%
# levels

# %%
tech.index.nlevels
# Out:
# 2

# %%
len(tech.index.levels)
# Out:
# 2

# %%
tech.index.levels[0]
# Out:
# Index(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07', '2014-01-08',
#        '2014-01-09', '2014-01-10', '2014-01-13', '2014-01-14', '2014-01-15',
#        ...
#        '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15', '2019-08-16',
#        '2019-08-19', '2019-08-20', '2019-08-21', '2019-08-22', '2019-08-23'],
#       dtype='object', name='date', length=1421)

# %%
tech.index.levels[1]
# Out:
# Index(['AAPL', 'AMZN', 'FB', 'GOOGL', 'MSFT'], dtype='object', name='name')

# %%
#levshape (to see length of each level)

# %%
tech.index.levshape
# Out:
# (1421, 5)

# %%
# multiindex internals
# levels - a list of list containing each label value for each of the lavels  in the multiindex
# names - a list containing the names of each level
# levshape - a tuple containing the length of each level
# values - use visual charts to communicate info more effectively

# %% [markdown]
# **Add another level**

# %%
tech
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume volume_type
# date       name
# 2014-01-02 FB     43257622      medium
# ...

# %%
tech.set_index('volume_type',append=True,inplace=True)

# %%
tech.index.nlevels
# Out:
# 3

# %%
tech.index.levels[2]
# Out:
# Index(['high', 'low', 'medium'], dtype='object', name='volume_type')

# %%
tech.index.values
# Out:
# array([('2014-01-02', 'FB', 'medium'), ('2014-01-02', 'AAPL', 'low'),
#        ('2014-01-02', 'GOOGL', 'medium'), ...,
#        ('2019-08-23', 'GOOGL', 'medium'),
#        ('2019-08-23', 'AMZN', 'medium'), ('2019-08-23', 'FB', 'medium')],
#       dtype=object)

# %%
# jan 2019 high volume trading days

# %%
tech.loc[(slice('2019-01-01','2019-01-31'),slice(None),'high'),:]
# Out:
#                              month  year  day     open    close     high  \
# date       name volume_type
# 2019-01-03 AAPL high             1  2019    3   143.98   142.19   145.72
# 2019-01-04 AMZN high             1  2019    4  1530.00  1575.39  1594.00
# 2019-01-08 AMZN high             1  2019    8  1664.69  1656.58  1676.61
# 2019-01-31 AMZN high             1  2019   31  1692.85  1718.73  1736.41
#            FB   high             1  2019   31   165.60   166.69   171.68
#
#                                  low    volume
# date       name volume_type
# 2019-01-03 AAPL high          142.00  91312195
# 2019-01-04 AMZN high         1518.31   9182575
# 2019-01-08 AMZN high         1616.61   8881428
# 2019-01-31 AMZN high         1679.08  10910338
#            FB   high          165.00  77233602

# %%
# all high volume trading days

# %%
tech.xs('high',level=2)
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-06 FB         1  2014    6    54.39    57.20    57.26    54.05
# 2014-01-07 FB         1  2014    7    57.67    57.92    58.55    57.22
# 2014-01-08 FB         1  2014    8    57.59    58.23    58.41    57.23
# 2014-01-09 FB         1  2014    9    58.66    57.22    58.96    56.65
# 2014-01-13 FB         1  2014   13    57.89    55.91    58.25    55.38
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-04-30 GOOGL      4  2019   30  1190.63  1198.96  1200.98  1183.00
# 2019-06-03 FB         6  2019    3   175.00   164.15   175.05   161.01
#            AMZN       6  2019    3  1760.01  1692.69  1766.29  1672.00
#            GOOGL      6  2019    3  1066.93  1038.74  1067.00  1027.03
# 2019-07-26 GOOGL      7  2019   26  1228.00  1245.22  1268.39  1228.00
#
#                     volume
# date       name
# 2014-01-06 FB     68974359
# ...

# %%
tech.xs(key=('high','FB'),level=(2,1))
# Out:
#             month  year  day    open   close    high     low    volume
# date
# 2014-01-06      1  2014    6   54.39   57.20   57.26   54.05  68974359
# 2014-01-07      1  2014    7   57.67   57.92   58.55   57.22  77329009
# 2014-01-08      1  2014    8   57.59   58.23   58.41   57.23  56800776
# 2014-01-09      1  2014    9   58.66   57.22   58.96   56.65  92349222
# 2014-01-13      1  2014   13   57.89   55.91   58.25   55.38  63106519
# ...           ...   ...  ...     ...     ...     ...     ...       ...
# 2018-10-31     10  2018   31  155.00  151.79  156.40  148.96  60101251
# 2018-12-19     12  2018   19  141.21  133.24  144.91  132.50  57404894
# 2018-12-21     12  2018   21  133.39  124.95  134.90  123.42  56901491
# 2019-01-31      1  2019   31  165.60  166.69  171.68  165.00  77233602
# 2019-06-03      6  2019    3  175.00  164.15  175.05  161.01  56059609
#
# [115 rows x 8 columns]

# %% [markdown]
# **Shuffling levels**

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       name  volume_type
# 2014-01-02 FB    medium           1  2014    2   54.86   54.71   55.22
#            AAPL  low              1  2014    2   79.38   79.02   79.58
#            GOOGL medium           1  2014    2  557.73  556.56  558.88
#            MSFT  medium           1  2014    2   37.35   37.16   37.40
#            AMZN  medium           1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       name  volume_type
# 2014-01-02 FB    medium        54.19  43257622
#            AAPL  low           78.86   8398851
#            GOOGL medium       554.13   1822719
#            MSFT  medium        37.10  30643745
#            AMZN  medium       394.02   2140246

# %%
#swaplevel

# %%
tech.swaplevel(2,1)
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.swaplevel(i=2,j=1)
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.swaplevel('volume_type','name')
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2    54.86    54.71    55.22
#            low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#                        AMZN       1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# 2019-08-23 medium      MSFT       8  2019   23   137.19   133.39   138.35
#                        AAPL       8  2019   23   209.43   202.64   212.05
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
# does not have inplace param. so if we want to inplace we must do re-assignment

# %%
tech=tech.swaplevel('volume_type','name')

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2   54.86   54.71   55.22
#            low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#                        AMZN       1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 medium      FB      54.19  43257622
#            low         AAPL    78.86   8398851
#            medium      GOOGL  554.13   1822719
#                        MSFT    37.10  30643745
#                        AMZN   394.02   2140246

# %%
# what if we have many levels and we need to reorder, one way is calling swaplevel more than once. another  way is,
# the reorder_levels()

# %%
tech.reorder_levels([2,0,1])
# Out:
#                               month  year  day     open    close     high  \
# name  date       volume_type
# FB    2014-01-02 medium           1  2014    2    54.86    54.71    55.22
# AAPL  2014-01-02 low              1  2014    2    79.38    79.02    79.58
# GOOGL 2014-01-02 medium           1  2014    2   557.73   556.56   558.88
# MSFT  2014-01-02 medium           1  2014    2    37.35    37.16    37.40
# AMZN  2014-01-02 medium           1  2014    2   398.80   397.97   399.36
# ...                             ...   ...  ...      ...      ...      ...
# MSFT  2019-08-23 medium           8  2019   23   137.19   133.39   138.35
# AAPL  2019-08-23 medium           8  2019   23   209.43   202.64   212.05
# GOOGL 2019-08-23 medium           8  2019   23  1185.17  1153.58  1195.67
# AMZN  2019-08-23 medium           8  2019   23  1793.03  1749.62  1804.90
# FB    2019-08-23 medium           8  2019   23   180.84   177.75   183.13
#
#                                   low    volume
# ...

# %%
tech.index.reorder_levels([2,1,0])
# Out:
# MultiIndex([(   'FB', 'medium', '2014-01-02'),
#             ( 'AAPL',    'low', '2014-01-02'),
#             ('GOOGL', 'medium', '2014-01-02'),
#             ( 'MSFT', 'medium', '2014-01-02'),
#             ( 'AMZN', 'medium', '2014-01-02'),
#             (   'FB', 'medium', '2014-01-03'),
#             ('GOOGL', 'medium', '2014-01-03'),
#             ( 'MSFT', 'medium', '2014-01-03'),
#             ( 'AAPL',    'low', '2014-01-03'),
#             ( 'AMZN', 'medium', '2014-01-03'),
#             ...
#             ( 'MSFT', 'medium', '2019-08-22'),
#             (   'FB',    'low', '2019-08-22'),
#             ( 'AMZN', 'medium', '2019-08-22'),
#             ( 'AAPL', 'medium', '2019-08-22'),
#             ('GOOGL',    'low', '2019-08-22'),
#             ( 'MSFT', 'medium', '2019-08-23'),
#             ( 'AAPL', 'medium', '2019-08-23'),
#             ('GOOGL', 'medium', '2019-08-23'),
#             ( 'AMZN', 'medium', '2019-08-23'),
#             (   'FB', 'medium', '2019-08-23')],
# ...

# %% [markdown]
# **Removing mulitindex levels**

# %%
# - df.droplevel()
# - df.reset_index(drop=bool)

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 medium      FB         1  2014    2   54.86   54.71   55.22
#            low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#                        AMZN       1  2014    2  398.80  397.97  399.36
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 medium      FB      54.19  43257622
#            low         AAPL    78.86   8398851
#            medium      GOOGL  554.13   1822719
#                        MSFT    37.10  30643745
#                        AMZN   394.02   2140246

# %%
# if we want to remove volume_type

# %%
tech.droplevel(1)
# Out:
#                   month  year  day     open    close     high      low  \
# date       name
# 2014-01-02 FB         1  2014    2    54.86    54.71    55.22    54.19
#            AAPL       1  2014    2    79.38    79.02    79.58    78.86
#            GOOGL      1  2014    2   557.73   556.56   558.88   554.13
#            MSFT       1  2014    2    37.35    37.16    37.40    37.10
#            AMZN       1  2014    2   398.80   397.97   399.36   394.02
# ...                 ...   ...  ...      ...      ...      ...      ...
# 2019-08-23 MSFT       8  2019   23   137.19   133.39   138.35   132.80
#            AAPL       8  2019   23   209.43   202.64   212.05   201.00
#            GOOGL      8  2019   23  1185.17  1153.58  1195.67  1150.00
#            AMZN       8  2019   23  1793.03  1749.62  1804.90  1745.23
#            FB         8  2019   23   180.84   177.75   183.13   176.66
#
#                     volume
# date       name
# 2014-01-02 FB     43257622
# ...

# %%
# but there is a problem that, when dropping there is no way around to keep this column as a regular column

# %%
# so we should use reset_index()

# %%
tech.reset_index(level=1) # same as tech.reset_index(level=1,drop=False)
# Out:
#                  volume_type  month  year  day     open    close     high  \
# date       name
# 2014-01-02 FB         medium      1  2014    2    54.86    54.71    55.22
#            AAPL          low      1  2014    2    79.38    79.02    79.58
#            GOOGL      medium      1  2014    2   557.73   556.56   558.88
#            MSFT       medium      1  2014    2    37.35    37.16    37.40
#            AMZN       medium      1  2014    2   398.80   397.97   399.36
# ...                      ...    ...   ...  ...      ...      ...      ...
# 2019-08-23 MSFT       medium      8  2019   23   137.19   133.39   138.35
#            AAPL       medium      8  2019   23   209.43   202.64   212.05
#            GOOGL      medium      8  2019   23  1185.17  1153.58  1195.67
#            AMZN       medium      8  2019   23  1793.03  1749.62  1804.90
#            FB         medium      8  2019   23   180.84   177.75   183.13
#
#                       low    volume
# date       name
# ...

# %%
# how about removing several levels at once

# %%
tech.reset_index(level=['volume_type','name'],drop=False)
# Out:
#            volume_type   name  month  year  day     open    close     high  \
# date
# 2014-01-02      medium     FB      1  2014    2    54.86    54.71    55.22
# 2014-01-02         low   AAPL      1  2014    2    79.38    79.02    79.58
# 2014-01-02      medium  GOOGL      1  2014    2   557.73   556.56   558.88
# 2014-01-02      medium   MSFT      1  2014    2    37.35    37.16    37.40
# 2014-01-02      medium   AMZN      1  2014    2   398.80   397.97   399.36
# ...                ...    ...    ...   ...  ...      ...      ...      ...
# 2019-08-23      medium   MSFT      8  2019   23   137.19   133.39   138.35
# 2019-08-23      medium   AAPL      8  2019   23   209.43   202.64   212.05
# 2019-08-23      medium  GOOGL      8  2019   23  1185.17  1153.58  1195.67
# 2019-08-23      medium   AMZN      8  2019   23  1793.03  1749.62  1804.90
# 2019-08-23      medium     FB      8  2019   23   180.84   177.75   183.13
#
#                 low    volume
# date
# ...

# %%
# how about a total reset

# %%
tech.reset_index()
# Out:
#             date volume_type   name  month  year  day     open    close  \
# 0     2014-01-02      medium     FB      1  2014    2    54.86    54.71
# 1     2014-01-02         low   AAPL      1  2014    2    79.38    79.02
# 2     2014-01-02      medium  GOOGL      1  2014    2   557.73   556.56
# 3     2014-01-02      medium   MSFT      1  2014    2    37.35    37.16
# 4     2014-01-02      medium   AMZN      1  2014    2   398.80   397.97
# ...          ...         ...    ...    ...   ...  ...      ...      ...
# 7100  2019-08-23      medium   MSFT      8  2019   23   137.19   133.39
# 7101  2019-08-23      medium   AAPL      8  2019   23   209.43   202.64
# 7102  2019-08-23      medium  GOOGL      8  2019   23  1185.17  1153.58
# 7103  2019-08-23      medium   AMZN      8  2019   23  1793.03  1749.62
# 7104  2019-08-23      medium     FB      8  2019   23   180.84   177.75
#
#          high      low    volume
# 0       55.22    54.19  43257622
# 1       79.58    78.86   8398851
# ...

# %% [markdown]
# **Multiindex sort_index()**

# %%
tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),slice('AAPL','FB')),'open':'low']
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# <ipython-input-56-74a49240cbdb> in <cell line: 1>()
# ----> 1 tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),slice('AAPL','FB')),'open':'low']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1245         with suppress(IndexingError):
#    1246             tup = self._expand_ellipsis(tup)
# -> 1247             return self._getitem_lowerdim(tup)
#    1248
# ...

# %%
# pandas is telling us we need to sort first

# %%
tech.sort_index(inplace=True)

# %%
tech.head()
# Out:
#                               month  year  day    open   close    high  \
# date       volume_type name
# 2014-01-02 low         AAPL       1  2014    2   79.38   79.02   79.58
#            medium      AMZN       1  2014    2  398.80  397.97  399.36
#                        FB         1  2014    2   54.86   54.71   55.22
#                        GOOGL      1  2014    2  557.73  556.56  558.88
#                        MSFT       1  2014    2   37.35   37.16   37.40
#
#                                  low    volume
# date       volume_type name
# 2014-01-02 low         AAPL    78.86   8398851
#            medium      AMZN   394.02   2140246
#                        FB      54.19  43257622
#                        GOOGL  554.13   1822719
#                        MSFT    37.10  30643745

# %%
tech.loc[(slice('2014-01-02','2014-04-02'),slice(None),slice('AAPL','FB')),'open':'low']
# Out:
#                                open   close    high     low
# date       volume_type name
# 2014-01-02 low         AAPL   79.38   79.02   79.58   78.86
#            medium      AMZN  398.80  397.97  399.36  394.02
#                        FB     54.86   54.71   55.22   54.19
# 2014-01-03 low         AAPL   79.00   77.28   79.10   77.20
#            medium      AMZN  398.29  396.44  402.71  396.22
# ...                             ...     ...     ...     ...
# 2014-04-01 low         AAPL   76.84   77.38   77.41   76.68
#            medium      AMZN  338.35  342.99  344.43  338.00
# 2014-04-02 high        FB     63.24   62.72   63.91   62.21
#            low         AAPL   77.48   77.51   77.64   77.18
#            medium      AMZN  345.99  341.96  348.30  340.38
#
# [189 rows x 4 columns]

# %%
# Always consider sorting the index
""" Advantage:
1. Improves retrieval performance ,which
becomes significant
- for large dataframes or
- frequence retieval

2. enables slicing syntax

3. overall a good practice when working with tabular data representations , including pandas, Excel, SQL etc.

"""
# Out:
# ' Advantage: \n1. Improves retrieval performance ,which\nbecomes significant\n- for large dataframes or\n- frequence retieval\n\n2. enables slicing syntax\n\n3. overall a good practice when working with tabular data representations , including pandas, Excel, SQL etc.\n\n'

# %%
# sorting different levels in different orders

# %%
tech.sort_index(level=(0,2),ascending=[False,True])
# Out:
#                               month  year  day     open    close     high  \
# date       volume_type name
# 2019-08-23 medium      AAPL       8  2019   23   209.43   202.64   212.05
#                        AMZN       8  2019   23  1793.03  1749.62  1804.90
#                        FB         8  2019   23   180.84   177.75   183.13
#                        GOOGL      8  2019   23  1185.17  1153.58  1195.67
#                        MSFT       8  2019   23   137.19   133.39   138.35
# ...                             ...   ...  ...      ...      ...      ...
# 2014-01-02 low         AAPL       1  2014    2    79.38    79.02    79.58
#            medium      AMZN       1  2014    2   398.80   397.97   399.36
#                        FB         1  2014    2    54.86    54.71    55.22
#                        GOOGL      1  2014    2   557.73   556.56   558.88
#                        MSFT       1  2014    2    37.35    37.16    37.40
#
#                                   low    volume
# ...

# %% [markdown]
# **More multiindex method**

# %%
tidx=tech.index

# %%
type(tidx)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
tidx.is_lexsorted()
# Out:
# <ipython-input-67-92cc64344631>:1: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   tidx.is_lexsorted()
# True

# %%
# in lexsort: 10 comes before 7 ( cz 1 < 7)

# %%
tidx.sortlevel(0,ascending=False,sort_remaining=True) # it sorts in levels
# Out:
# (MultiIndex([('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
#              ('2019-08-23', 'medium',  'AAPL'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ...
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
#              ('2014-01-02', 'medium',  'AMZN'),
# ...

# %%
# sorting multiple level at once
tidx.sortlevel((0,1,2),ascending=[True,True,False])
# Out:
# (MultiIndex([('2014-01-02',    'low',  'AAPL'),
#              ('2014-01-02', 'medium',  'MSFT'),
#              ('2014-01-02', 'medium', 'GOOGL'),
#              ('2014-01-02', 'medium',    'FB'),
#              ('2014-01-02', 'medium',  'AMZN'),
#              ('2014-01-03',    'low',  'AAPL'),
#              ('2014-01-03', 'medium',  'MSFT'),
#              ('2014-01-03', 'medium', 'GOOGL'),
#              ('2014-01-03', 'medium',    'FB'),
#              ('2014-01-03', 'medium',  'AMZN'),
#              ...
#              ('2019-08-22',    'low', 'GOOGL'),
#              ('2019-08-22',    'low',    'FB'),
#              ('2019-08-22', 'medium',  'MSFT'),
#              ('2019-08-22', 'medium',  'AMZN'),
#              ('2019-08-22', 'medium',  'AAPL'),
#              ('2019-08-23', 'medium',  'MSFT'),
#              ('2019-08-23', 'medium', 'GOOGL'),
#              ('2019-08-23', 'medium',    'FB'),
#              ('2019-08-23', 'medium',  'AMZN'),
# ...

# %%
tidx.set_names(['Trading Date','Volume Category','Ticker'],inplace=True)

# %%
tech.head()
# Out:
#                                      month  year  day    open   close    high  \
# Trading Date Volume Category Ticker
# 2014-01-02   low             AAPL        1  2014    2   79.38   79.02   79.58
#              medium          AMZN        1  2014    2  398.80  397.97  399.36
#                              FB          1  2014    2   54.86   54.71   55.22
#                              GOOGL       1  2014    2  557.73  556.56  558.88
#                              MSFT        1  2014    2   37.35   37.16   37.40
#
#                                         low    volume
# Trading Date Volume Category Ticker
# 2014-01-02   low             AAPL     78.86   8398851
#              medium          AMZN    394.02   2140246
#                              FB       54.19  43257622
#                              GOOGL   554.13   1822719
#                              MSFT     37.10  30643745

# %%
tidx.to_flat_index() # very useful for visualize
# Out:
# Index([    ('2014-01-02', 'low', 'AAPL'),  ('2014-01-02', 'medium', 'AMZN'),
#           ('2014-01-02', 'medium', 'FB'), ('2014-01-02', 'medium', 'GOOGL'),
#         ('2014-01-02', 'medium', 'MSFT'),     ('2014-01-03', 'low', 'AAPL'),
#         ('2014-01-03', 'medium', 'AMZN'),    ('2014-01-03', 'medium', 'FB'),
#        ('2014-01-03', 'medium', 'GOOGL'),  ('2014-01-03', 'medium', 'MSFT'),
#        ...
#              ('2019-08-22', 'low', 'FB'),    ('2019-08-22', 'low', 'GOOGL'),
#         ('2019-08-22', 'medium', 'AAPL'),  ('2019-08-22', 'medium', 'AMZN'),
#         ('2019-08-22', 'medium', 'MSFT'),  ('2019-08-23', 'medium', 'AAPL'),
#         ('2019-08-23', 'medium', 'AMZN'),    ('2019-08-23', 'medium', 'FB'),
#        ('2019-08-23', 'medium', 'GOOGL'),  ('2019-08-23', 'medium', 'MSFT')],
#       dtype='object', length=7105)

# %%
tech.close
# Out:
# Trading Date  Volume Category  Ticker
# 2014-01-02    low              AAPL        79.02
#               medium           AMZN       397.97
#                                FB          54.71
#                                GOOGL      556.56
#                                MSFT        37.16
#                                           ...
# 2019-08-23    medium           AAPL       202.64
#                                AMZN      1749.62
#                                FB         177.75
#                                GOOGL     1153.58
#                                MSFT       133.39
# Name: close, Length: 7105, dtype: float64

# %% [markdown]
# **Reshaping with stack**

# %%
tech.head(10)
# Out:
#                                      month  year  day    open   close    high  \
# Trading Date Volume Category Ticker
# 2014-01-02   low             AAPL        1  2014    2   79.38   79.02   79.58
#              medium          AMZN        1  2014    2  398.80  397.97  399.36
#                              FB          1  2014    2   54.86   54.71   55.22
#                              GOOGL       1  2014    2  557.73  556.56  558.88
#                              MSFT        1  2014    2   37.35   37.16   37.40
# 2014-01-03   low             AAPL        1  2014    3   79.00   77.28   79.10
#              medium          AMZN        1  2014    3  398.29  396.44  402.71
#                              FB          1  2014    3   55.00   54.56   55.65
#                              GOOGL       1  2014    3  557.50  552.50  558.47
#                              MSFT        1  2014    3   37.20   36.91   37.22
#
#                                         low    volume
# ...

# %%
stacked=tech.stack()

# %%
stacked.head(10)
# Out:
# Trading Date  Volume Category  Ticker
# 2014-01-02    low              AAPL    month           1.00
#                                        year         2014.00
#                                        day             2.00
#                                        open           79.38
#                                        close          79.02
#                                        high           79.58
#                                        low            78.86
#                                        volume    8398851.00
#               medium           AMZN    month           1.00
#                                        year         2014.00
# dtype: float64

# %%
type(stacked)
# Out:
# pandas.core.series.Series

# %%
stacked.index.nlevels
# Out:
# 4

# %%
names=stacked.index.names

# %%
names
# Out:
# FrozenList(['Trading Date', 'Volume Category', 'Ticker', None])

# %%
stacked.index.set_names([*names[:-1],'previously a column axis'],inplace=True)

# %%
*names[:-1]
# Out:
#   File "<ipython-input-93-1e57d9c9fd41>", line 1
#     *names[:-1]
#     ^
# SyntaxError: can't use starred expression here

# %%
stacked.head(10)
# Out:
# Trading Date  Volume Category  Ticker  previously a column axis
# 2014-01-02    low              AAPL    month                             1.00
#                                        year                           2014.00
#                                        day                               2.00
#                                        open                             79.38
#                                        close                            79.02
#                                        high                             79.58
#                                        low                              78.86
#                                        volume                      8398851.00
#               medium           AMZN    month                             1.00
#                                        year                           2014.00
# dtype: float64

# %% [markdown]
# **The flipside: unstack()**

# %%
stacked
# Out:
# Trading Date  Volume Category  Ticker  previously a column axis
# 2014-01-02    low              AAPL    month                              1.00
#                                        year                            2014.00
#                                        day                                2.00
#                                        open                              79.38
#                                        close                             79.02
#                                                                       ...
# 2019-08-23    medium           MSFT    open                             137.19
#                                        close                            133.39
#                                        high                             138.35
#                                        low                              132.80
#                                        volume                      38515386.00
# Length: 56840, dtype: float64

# %%
stacked.unstack()
# Out:
# previously a column axis             month    year   day     open    close  \
# Trading Date Volume Category Ticker
# 2014-01-02   low             AAPL      1.0  2014.0   2.0    79.38    79.02
#              medium          AMZN      1.0  2014.0   2.0   398.80   397.97
#                              FB        1.0  2014.0   2.0    54.86    54.71
#                              GOOGL     1.0  2014.0   2.0   557.73   556.56
#                              MSFT      1.0  2014.0   2.0    37.35    37.16
# ...                                    ...     ...   ...      ...      ...
# 2019-08-23   medium          AAPL      8.0  2019.0  23.0   209.43   202.64
#                              AMZN      8.0  2019.0  23.0  1793.03  1749.62
#                              FB        8.0  2019.0  23.0   180.84   177.75
#                              GOOGL     8.0  2019.0  23.0  1185.17  1153.58
#                              MSFT      8.0  2019.0  23.0   137.19   133.39
#
# ...

# %%
# unstack takes inner most level and make it to column level

# %%
stacked.unstack().unstack() # both index and column have now 2 levels
# Out:
# previously a column axis     month                         year          \
# Ticker                        AAPL AMZN   FB GOOGL MSFT    AAPL    AMZN
# Trading Date Volume Category
# 2014-01-02   low               1.0  NaN  NaN   NaN  NaN  2014.0     NaN
#              medium            NaN  1.0  1.0   1.0  1.0     NaN  2014.0
# 2014-01-03   low               1.0  NaN  NaN   NaN  NaN  2014.0     NaN
#              medium            NaN  1.0  1.0   1.0  1.0     NaN  2014.0
# 2014-01-06   high              NaN  NaN  1.0   NaN  NaN     NaN     NaN
# ...                            ...  ...  ...   ...  ...     ...     ...
# 2019-08-21   low               NaN  8.0  8.0   8.0  8.0     NaN  2019.0
#              medium            8.0  NaN  NaN   NaN  NaN  2019.0     NaN
# 2019-08-22   low               NaN  NaN  8.0   8.0  NaN     NaN     NaN
#              medium            8.0  8.0  NaN   NaN  8.0  2019.0  2019.0
# 2019-08-23   medium            8.0  8.0  8.0   8.0  8.0  2019.0  2019.0
#
# ...

# %%
stacked.unstack().unstack(fill_value='-')
# Out:
# previously a column axis     month                         year          \
# Ticker                        AAPL AMZN   FB GOOGL MSFT    AAPL    AMZN
# Trading Date Volume Category
# 2014-01-02   low               1.0    -    -     -    -  2014.0       -
#              medium              -  1.0  1.0   1.0  1.0       -  2014.0
# 2014-01-03   low               1.0    -    -     -    -  2014.0       -
#              medium              -  1.0  1.0   1.0  1.0       -  2014.0
# 2014-01-06   high                -    -  1.0     -    -       -       -
# ...                            ...  ...  ...   ...  ...     ...     ...
# 2019-08-21   low                 -  8.0  8.0   8.0  8.0       -  2019.0
#              medium            8.0    -    -     -    -  2019.0       -
# 2019-08-22   low                 -    -  8.0   8.0    -       -       -
#              medium            8.0  8.0    -     -  8.0  2019.0  2019.0
# 2019-08-23   medium            8.0  8.0  8.0   8.0  8.0  2019.0  2019.0
#
# ...

# %%
# what is we want to unstack not the inner most but a specific one

# %%
stacked
# Out:
# Trading Date  Volume Category  Ticker  previously a column axis
# 2014-01-02    low              AAPL    month                              1.00
#                                        year                            2014.00
#                                        day                                2.00
#                                        open                              79.38
#                                        close                             79.02
#                                                                       ...
# 2019-08-23    medium           MSFT    open                             137.19
#                                        close                            133.39
#                                        high                             138.35
#                                        low                              132.80
#                                        volume                      38515386.00
# Length: 56840, dtype: float64

# %%
stacked.unstack(level=1)
# Out:
# Volume Category                               high      low       medium
# Trading Date Ticker previously a column axis
# 2014-01-02   AAPL   month                      NaN     1.00          NaN
#                     year                       NaN  2014.00          NaN
#                     day                        NaN     2.00          NaN
#                     open                       NaN    79.38          NaN
#                     close                      NaN    79.02          NaN
# ...                                            ...      ...          ...
# 2019-08-23   MSFT   open                       NaN      NaN       137.19
#                     close                      NaN      NaN       133.39
#                     high                       NaN      NaN       138.35
#                     low                        NaN      NaN       132.80
#                     volume                     NaN      NaN  38515386.00
#
# [56840 rows x 3 columns]

# %%
stacked.unstack(level='Ticker')
# Out:
# Ticker                                                        AAPL  \
# Trading Date Volume Category previously a column axis
# 2014-01-02   low             month                            1.00
#                              year                          2014.00
#                              day                              2.00
#                              open                            79.38
#                              close                           79.02
# ...                                                            ...
# 2019-08-23   medium          open                           209.43
#                              close                          202.64
#                              high                           212.05
#                              low                            201.00
#                              volume                    46882843.00
#
# Ticker                                                       AMZN  \
# ...

# %% [markdown]
# **Creating multilevel columns manually**

# %%
tech.reset_index(inplace=True)

# %%
tech
# Out:
#      Trading Date Volume Category Ticker  month  year  day     open    close  \
# 0      2014-01-02             low   AAPL      1  2014    2    79.38    79.02
# 1      2014-01-02          medium   AMZN      1  2014    2   398.80   397.97
# 2      2014-01-02          medium     FB      1  2014    2    54.86    54.71
# 3      2014-01-02          medium  GOOGL      1  2014    2   557.73   556.56
# 4      2014-01-02          medium   MSFT      1  2014    2    37.35    37.16
# ...           ...             ...    ...    ...   ...  ...      ...      ...
# 7100   2019-08-23          medium   AAPL      8  2019   23   209.43   202.64
# 7101   2019-08-23          medium   AMZN      8  2019   23  1793.03  1749.62
# 7102   2019-08-23          medium     FB      8  2019   23   180.84   177.75
# 7103   2019-08-23          medium  GOOGL      8  2019   23  1185.17  1153.58
# 7104   2019-08-23          medium   MSFT      8  2019   23   137.19   133.39
#
#          high      low    volume
# ...

# %%
# let's build one manually
# criteria:
# 2-level multiindex column axis, containing:
# trading volume (high and low) and tickers (MSFT & AMZN)
# 10 random closing price observations

# %%
# step 1: create multiindex

# %%
cols=pd.MultiIndex.from_product([['low','high'],['MSFT','AMZN']],names=['Volume Category','Ticker'])

# %%
cols
# Out:
# MultiIndex([( 'low', 'MSFT'),
#             ( 'low', 'AMZN'),
#             ('high', 'MSFT'),
#             ('high', 'AMZN')],
#            names=['Volume Category', 'Ticker'])

# %%
# step 2: prepare the underlying data

# %%
low = tech['Volume Category']=='low'
high= tech['Volume Category']=='high'
msft= tech['Ticker']=='MSFT'
amzn= tech['Ticker']=='AMZN'

# %%
data = [
    tech[low & msft].close.sample(10).values,
    tech[low & amzn].close.sample(10).values,
    tech[high & msft].close.sample(10).values,
    tech[high & amzn].close.sample(10).values
]
print(data)
# Out:
# [array([ 72.83, 103.07, 120.33,  74.26,  65.73,  77.65,  99.05,  55.67,
#         74.41,  85.72]), array([ 770.62,  303.03,  436.29,  384.61,  780.22, 1168.36, 1801.38,
#         767.58,  531.52,  426.57]), array([49.83, 46.13, 37.84, 43.07, 42.71, 43.48, 47.52, 40.16, 55.91,
#        55.09]), array([1719.36,  299.9 ,  482.18,  403.01,  311.78, 1668.4 ,  771.88,
#        1517.96,  324.01,  354.53])]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-91e9be1d84c9> in <cell line: 1>()
# ----> 1 list(*data)
#
# TypeError: list expected at most 1 argument, got 4

# %%
data =[ [*i] for i in zip(*data)]

# %%
data
# Out:
# [[45.01, 767.58, 103.73, 1598.01],
#  [41.11, 423.67, 48.64, 297.25],
#  [62.9, 1001.81, 102.32, 1572.62],
#  [75.21, 310.35, 41.68, 1808.0],
#  [120.33, 401.01, 40.16, 1377.45],
#  [73.98, 759.22, 51.78, 1530.42],
#  [72.72, 854.59, 37.84, 635.35],
#  [119.93, 426.57, 47.87, 1520.91],
#  [76.29, 1581.4, 47.52, 742.38],
#  [85.4, 371.92, 43.48, 303.83]]

# %%
df=pd.DataFrame(data,columns=cols)

# %%
df
# Out:
# Volume Category     low            high
# Ticker             MSFT     AMZN   MSFT     AMZN
# 0                 72.83   770.62  49.83  1719.36
# 1                103.07   303.03  46.13   299.90
# 2                120.33   436.29  37.84   482.18
# 3                 74.26   384.61  43.07   403.01
# 4                 65.73   780.22  42.71   311.78
# 5                 77.65  1168.36  43.48  1668.40
# 6                 99.05  1801.38  47.52   771.88
# 7                 55.67   767.58  40.16  1517.96
# 8                 74.41   531.52  55.91   324.01
# 9                 85.72   426.57  55.09   354.53

# %%
df.columns.levels
# Out:
# FrozenList([['high', 'low'], ['AMZN', 'MSFT']])

# %%
# need to check : https://www.scaler.com/topics/asterisk-python/

# %% [markdown]
# **An easier way: transpose()**

# %%
# multiindex columns = set_index() + transpose()
# set_index() : create multiindex
# transpose() :swap columns with index

# %%
tech
# Out:
#      Trading Date Volume Category Ticker  month  year  day     open    close  \
# 0      2014-01-02             low   AAPL      1  2014    2    79.38    79.02
# 1      2014-01-02          medium   AMZN      1  2014    2   398.80   397.97
# 2      2014-01-02          medium     FB      1  2014    2    54.86    54.71
# 3      2014-01-02          medium  GOOGL      1  2014    2   557.73   556.56
# 4      2014-01-02          medium   MSFT      1  2014    2    37.35    37.16
# ...           ...             ...    ...    ...   ...  ...      ...      ...
# 7100   2019-08-23          medium   AAPL      8  2019   23   209.43   202.64
# 7101   2019-08-23          medium   AMZN      8  2019   23  1793.03  1749.62
# 7102   2019-08-23          medium     FB      8  2019   23   180.84   177.75
# 7103   2019-08-23          medium  GOOGL      8  2019   23  1185.17  1153.58
# 7104   2019-08-23          medium   MSFT      8  2019   23   137.19   133.39
#
#          high      low    volume
# ...

# %%
tech.set_index(['Trading Date','Volume Category'])
# Out:
#                              Ticker  month  year  day     open    close  \
# Trading Date Volume Category
# 2014-01-02   low               AAPL      1  2014    2    79.38    79.02
#              medium            AMZN      1  2014    2   398.80   397.97
#              medium              FB      1  2014    2    54.86    54.71
#              medium           GOOGL      1  2014    2   557.73   556.56
#              medium            MSFT      1  2014    2    37.35    37.16
# ...                             ...    ...   ...  ...      ...      ...
# 2019-08-23   medium            AAPL      8  2019   23   209.43   202.64
#              medium            AMZN      8  2019   23  1793.03  1749.62
#              medium              FB      8  2019   23   180.84   177.75
#              medium           GOOGL      8  2019   23  1185.17  1153.58
#              medium            MSFT      8  2019   23   137.19   133.39
#
#                                  high      low    volume
# ...

# %%
tech.set_index(['Trading Date','Volume Category']).transpose()
# Out:
# Trading Date    2014-01-02                                       2014-01-03  \
# Volume Category        low   medium    medium   medium    medium        low
# Ticker                AAPL     AMZN        FB    GOOGL      MSFT       AAPL
# month                    1        1         1        1         1          1
# year                  2014     2014      2014     2014      2014       2014
# day                      2        2         2        2         2          3
# open                 79.38    398.8     54.86   557.73     37.35       79.0
# close                79.02   397.97     54.71   556.56     37.16      77.28
# high                 79.58   399.36     55.22   558.88      37.4       79.1
# low                  78.86   394.02     54.19   554.13      37.1       77.2
# volume             8398851  2140246  43257622  1822719  30643745   14043410
#
# Trading Date                                           ... 2019-08-22  \
# ...

# %% [markdown]
# **What about panels?**

# %%
# panel vs multiindex df
# prefer df.MultiIndex for new projects
# many of the same pandas concept apply
# older docs still available online for panel

# %% [markdown]
# **SKILL CHALLENGE**

# %% [markdown]
# *1. Change the index of the tech dataframe to a 3 level multiindex containing year, month and day on levels 0,1,2 respectively . assign it to tech_df3*

# %%
tech.head()
# Out:
#   Trading Date Volume Category Ticker  month  year  day    open   close  \
# 0   2014-01-02             low   AAPL      1  2014    2   79.38   79.02
# 1   2014-01-02          medium   AMZN      1  2014    2  398.80  397.97
# 2   2014-01-02          medium     FB      1  2014    2   54.86   54.71
# 3   2014-01-02          medium  GOOGL      1  2014    2  557.73  556.56
# 4   2014-01-02          medium   MSFT      1  2014    2   37.35   37.16
#
#      high     low    volume
# 0   79.58   78.86   8398851
# 1  399.36  394.02   2140246
# 2   55.22   54.19  43257622
# 3  558.88  554.13   1822719
# 4   37.40   37.10  30643745

# %%
tech_df3=tech.set_index(['year','month','day'])
tech_df3.index.nlevels
# Out:
# 3

# %%
tech_df3.head()
# Out:
#                Trading Date Volume Category Ticker    open   close    high  \
# year month day
# 2014 1     2     2014-01-02             low   AAPL   79.38   79.02   79.58
#            2     2014-01-02          medium   AMZN  398.80  397.97  399.36
#            2     2014-01-02          medium     FB   54.86   54.71   55.22
#            2     2014-01-02          medium  GOOGL  557.73  556.56  558.88
#            2     2014-01-02          medium   MSFT   37.35   37.16   37.40
#
#                    low    volume
# year month day
# 2014 1     2     78.86   8398851
#            2    394.02   2140246
#            2     54.19  43257622
#            2    554.13   1822719
#            2     37.10  30643745

# %% [markdown]
# *2. From the tech_df3 dataset, select all the trading days from the year 2019. In additoin add the existing column axis as the 4th level of the multiindex.assign it to tech_series*

# %%
tech_series=tech_df3.loc[(2019,slice(None),slice(None))]

# %%
tech_series
# Out:
#           Trading Date Volume Category Ticker     open    close     high  \
# month day
# 1     2     2019-01-02          medium   AAPL   154.89   157.92   158.85
#       2     2019-01-02          medium   AMZN  1465.20  1539.13  1553.36
#       2     2019-01-02          medium     FB   128.99   135.68   137.51
#       2     2019-01-02          medium  GOOGL  1027.20  1054.68  1060.79
#       2     2019-01-02          medium   MSFT    99.55   101.12   101.75
# ...                ...             ...    ...      ...      ...      ...
# 8     23    2019-08-23          medium   AAPL   209.43   202.64   212.05
#       23    2019-08-23          medium   AMZN  1793.03  1749.62  1804.90
#       23    2019-08-23          medium     FB   180.84   177.75   183.13
#       23    2019-08-23          medium  GOOGL  1185.17  1153.58  1195.67
#       23    2019-08-23          medium   MSFT   137.19   133.39   138.35
#
#                low    volume
# month day
# 1     2     154.23  37039737
# ...

# %%
tech_series=tech_df3.xs((2019,slice(None),slice(None)),level=(0,1,2)).stack()

# %% [markdown]
# *3. From the tech_series dataframe, find the average close price and its std*

# %%
tech_series
# Out:
# year  month  day
# 2019  1      2    Trading Date       2019-01-02
#                   Volume Category        medium
#                   Ticker                   AAPL
#                   open                   154.89
#                   close                  157.92
#                                         ...
#       8      23   open                   137.19
#                   close                  133.39
#                   high                   138.35
#                   low                     132.8
#                   volume               38515386
# Length: 6520, dtype: object

# %%
tech_series.xs((slice(None),slice(None),slice(None),'close'),level=(0,1,2,3)).mean()
# Out:
# 686.3976196319019

# %%
tech_series.xs((slice(None),slice(None),slice(None),'close'),level=(0,1,2,3)).std()
# Out:
# 677.2268499713305

# %%
tech_series.xs((slice(None),slice(None),slice(None),'close'),level=(0,1,2,3)).apply({'Average':'mean','Standard deviatin':'std'})
# Out:
# Average              686.39762
# Standard deviatin    677.22685
# dtype: float64
